# %% [markdown]
# ## Predicting Default Risk

# %% [markdown]
# ### Step 1: Business and Data Understanding

# %% [markdown]
# #### problem :
# You are a loan officer at a young and small bank (been in operations for two years) that needs to come up with an efficient solution to classify new customers on whether they can be approved for a loan or not. You'll use a series of classification models to figure out the best model and provide a list of creditworthy customers to your manager.

# %% [markdown]
# What decisions need to be made?

# %% [markdown]
# there are 500 a new custmer, we make decision to can be approved for a loan or not

# %% [markdown]
# What data is needed to inform those decisions?

# %% [markdown]
# 1- The old custmers we have to build the model
# 2- The new custmer to apply the model

# %% [markdown]
# What kind of model (Continuous, Binary, Non-Binary, Time-Series) do we need to use to help make these decisions?

# %% [markdown]
# Binary classification model such as logistics regression , forest model , boosted tree, and decision tree used to analyze and determine creditworthy customers

# %% [markdown]
# ### Step 2: Explore and Cleanup the Data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The correlation more then 0.70

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There are 7 field should be removed:

# %% [markdown]
# 1-Guarantors
# 2-Occupation
# 3-Foreign-Worker
# 4-No-of-dependents
# 5-Concurrent-Credits
# ##### all previous  fields removed because low variability base on histogam
# 6-Duration-in-Current-address
# ##### Duration-in-Current-address is removed because there a lot of missing value
# 7-Telephone
# ##### because doesn't make sense and doesn't impact about we decision

# %% [markdown]
# The Age year has 2% missing value and replace to median of all years custmer
# The median is 33 because doen't impact of outlier and impact the count of years
# customer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 3. Train your Classification Models

# %% [markdown]
# we choose 70% to create the Estimation set and 30% to create the Validation set

# %% [markdown]
# and then use four model
# * Logistic Regression
# * Decision Tree
# * Forest Tree
# * Boosted model

# %% [markdown]
# 1-Logistic Regression

# %% [markdown]
# Which predictor variables are significant or the most important? Please show the p-values or variable importance charts for all of your predictor variables?
#
# base on report the predictor variables singnificant where p value<0.05:
#
# Account.BalanceSome
# Payment.Status.of.Previous.CreditSome Problems
# PurposeNew car
# Credit.Amount
# Length.of.current.employment< 1yr
# Instalment.per.cent
#
#  The overall accuracy is 76.0%.
#
# Accuracy for creditworthy is 87.6% while accuracy for non-creditworthy is 48.8%. The model seems to be biased towards predicting customers as non-creditworthy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# 2-Decision Tree

# %% [markdown]
# The important three variable are:
#
#
# 1-Account.Balance
#
# 2-value.Saving.Stock
#
# 3-Duraion of Credit Month
#
#  The overall accuracy is 74.67%.
#
# Accuracy for creditworthy is 86.6% while accuracy for non-creditworthy is 46.6%. The model seems to be biased towards predicting customers as non-creditworthy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# 3-Forest Tree

# %% [markdown]
# The important three variable are:
#
# 1-Credit.Amount
#
# 2-Age.years
#
# 2-Duraion of Credit Month
#
#
#  The overall accuracy is 79.33%.
#
# Accuracy for creditworthy is 97.1% while accuracy for non-creditworthy is 37.7%. The model seems to be biased towards predicting customers as non-creditworthy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# 4- Boosted model

# %% [markdown]
# The important two variable are:
#
# 1-Credit.Amount
#
# 1-Account.Balance
#
#
#  The overall accuracy is 78.6%.
#
# Accuracy for creditworthy is 96.1% while accuracy for non-creditworthy is 37.7%. The model seems to be biased towards predicting customers as non-creditworthy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# ## Write-Up

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I decided to use the Forest model because is highest accuracy at 79.33
# % ,The accuracy of Creditworthy is 97.1% is gereater than all models , The accuracy of Non-Creditworthy is 37.7% is equals Bosted Modal and less than Decision Tree and Logistic Regression

# %% [markdown]
# #### ROC graph

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The yallow represent forst Tree and has been batter then other models.

# %% [markdown]
# #### Bias in the Confusion Matrices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we have 102 records that are predicted Creditworthy that were actually Creditworthy and we have 26 records that were predicted Creditworthy that were actually Non-Creditworthy
#
# we have 3 records that are predicted Non-Creditworthy that were actually Creditworthy and we have 19 records that were predicted Non-Creditothy that were actrally Non-Creditworthy

# %% [markdown]
# How many individuals are Creditworthy?
#
# 408 are Creditworthy and 92 are Non-Creditworthy

# %% [markdown]
# ### workflow

# %% [markdown]
# ![image.png](attachment:image.png)
